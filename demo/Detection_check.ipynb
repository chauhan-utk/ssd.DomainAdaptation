# %%
import os
import numpy as np

# %%
path = "/users/gpu/utkrsh/data/PennDataset_detections/"

# %%
directories = os.listdir(path)

# %%
d = []
for directory in directories:
    files = os.listdir(path+directory+"/")
    for file in files:
        try:
            var = np.load(file)
        except OSError:
            if directory not in d:
                d+= [directory]

# %%
d
# Out:
# ['1943',
#  '0852',
#  '0636',
#  '1207',
#  '0802',
#  '0739',
#  '1835',
#  '0354',
#  '1561',
#  '2225',
#  '1844',
#  '2265',
#  '2229',
#  '1497',
#  '0434',
#  '2246',
#  '1212',
#  '1136',
#  '2045',
#  '0766',
#  '1823',
#  '1096',
#  '0032',
#  '0415',
#  '0928',
#  '0997',
#  '2021',
#  '0680',
#  '1506',
#  '0546',
#  '0074',
#  '1057',
#  '1564',
#  '2293',
#  '0870',
#  '1157',
#  '1927',
#  '0113',
#  '2104',
#  '0274',
#  '2027',
#  '0369',
#  '0184',
#  '0947',
#  '1379',
#  '1618',
#  '0538',
#  '0384',
#  '0439',
#  '1052',
#  '0078',
#  '1223',
#  '2240',
#  '0209',
#  '0781',
#  '0060',
#  '0993',
#  '0418',
#  '1711',
#  '2173',
#  '2237',
#  '0087',
#  '0477',
#  '2298',
#  '1526',
#  '1000',
#  '0528',
#  '0562',
#  '0684',
#  '0620',
#  '0062',
#  '1719',
#  '1536',
#  '1851',
#  '1140',
#  '2323',
#  '1109',
#  '0077',
#  '0732',
#  '1671',
#  '1277',
#  '0560',
#  '1293',
#  '1508',
#  '0798',
#  '1100',
#  '1939',
#  '1475',
#  '1387',
#  '1450',
# ...
