# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import numpy as np
import cv2

# %matplotlib inline
from matplotlib import pyplot as plt

# %%
file = "/users/gpu/prabudc1/Penndata/frames/0290/000003.jpg"
predictions = "/users/gpu/utkrsh/data/PennDataset_detections/0298/000004.jpg_pred.npy"

# %%
image = cv2.imread(file, cv2.IMREAD_COLOR)
colors = plt.cm.hsv(np.linspace(0, 1, 21)).tolist()

# %%
detections = np.load(predictions)

# %%
detections.shape
# Out:
# (1, 4)

# %%
type(detections[0])
# Out:
# numpy.ndarray

# %%
blah = detections[0]

# %%
blah.shape
# Out:
# (4,)

# %%
type(blah[1])
# Out:
# numpy.float64

# %%
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(rgb_image)

currentAxis = plt.gca()

for i in range(detections.shape[0]):
    cd = detections[i]
    currentAxis.add_patch(plt.Rectangle((cd[0],cd[1]),cd[2],cd[3],
                                        fill=False, edgecolor=colors[15], linewidth=2))
    
plt.show()
